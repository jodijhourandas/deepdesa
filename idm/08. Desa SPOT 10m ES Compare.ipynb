# %% [markdown]
# # Desa SPOT 10m ES Compare

# %% [markdown]
# Pada proses clipping citra , ditemukan 577 desa dengan tutupan awan tinggi untuk satelit SPOT 6-7 seperti yang dapat dilihat pada Gambar 6. Sehingga pada kajian efek resolusi citra terhadap model akan dilakukan pada 5380 desa dan 200.200 SLS.
#
# Dari hasil sebelumnya, dapat dilihat densenet121 adalah model terbaik untuk mengklasfikari desa urban dan rural dengan model data : SLS dan Square Neighbour. Skenario tersebut akan digunakan untuk menguji efek resolusi terhadap klasifikasi dengan melakukan train terhadapa uncovered desa baik dengan data sentinel maupun spot.
#
# Pada bagian ini dilakukan pemodelan untuk SPOT dentan tingkat desa.

# %%
import fastai
from fastai.vision.all import *
import os
from PIL import Image
import pandas as pd
import shutil
import torch

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3050 Laptop GPU'

# %% [markdown]
# #### Preprocessing

# %%
idm = pd.read_csv("C:/Users/jwst2/Python/tesis/dataset/newdata_edit.csv")

# %%
idm = idm.drop_duplicates("bps_kelurahan_kode")

# %%
idm.groupby("status").count()
# Out:
#             kemendagri_kelurahan_kode  bps_kelurahan_kode  bps_kelurahan_nama  \
# status
# BERKEMBANG                       3290                3290                3223
# MAJU                             1631                1631                1584
# MANDIRI                           270                 270                 267
# TERTINGGAL                        121                 121                 119
#
#             kemendagri_kelurahan_nama    id  kemendagri_provinsi_kode  \
# status
# BERKEMBANG                       3290  3290                      3290
# MAJU                             1631  1631                      1631
# MANDIRI                           270   270                       270
# TERTINGGAL                        121   121                       121
#
#             kemendagri_kota_kode  kemendagri_kecamatan_kode  \
# status
# BERKEMBANG                  3290                       3290
# MAJU                        1631                       1631
# MANDIRI                      270                        270
# TERTINGGAL                   121                        121
#
#             kemendagri_provinsi_nama  kemendagri_kota_nama  ...  status_adm  \
# status                                                      ...
# BERKEMBANG                      3290                  3290  ...           0
# MAJU                            1631                  1631  ...           0
# MANDIRI                          270                   270  ...           0
# TERTINGGAL                       121                   121  ...           0
#
#             nama  id_kecamatan  nama_kecamatan  id_kabupaten  nama_kabupaten  \
# status
# BERKEMBANG  3290          3290            3290          3290            3290
# MAJU        1631          1631            1631          1631            1631
# MANDIRI      270           270             270           270             270
# TERTINGGAL   121           121             121           121             121
#
#              iks   ike   ikl  avg_idm
# status
# BERKEMBANG  3290  3290  3290     3290
# MAJU        1631  1631  1631     1631
# MANDIRI      270   270   270      270
# TERTINGGAL   121   121   121      121
#
# [4 rows x 30 columns]

# %%
idm[idm.bps_kelurahan_kode ==3209100011]
# Out:
#       kemendagri_kelurahan_kode  bps_kelurahan_kode status bps_kelurahan_nama  \
# 3070                 3209132011        3.209100e+09   MAJU                NaN
#
#      kemendagri_kelurahan_nama    id  kemendagri_provinsi_kode  \
# 3070                     BEBER  3038                        32
#
#       kemendagri_kota_kode kemendagri_kecamatan_kode kemendagri_provinsi_nama  \
# 3070                 32.09                  32.09.13               JAWA BARAT
#
#       ... status_adm   nama  id_kecamatan  nama_kecamatan  id_kabupaten  \
# 3070  ...        NaN  BEBER      320913.0           BEBER        3209.0
#
#          nama_kabupaten     iks  ike     ikl  avg_idm
# 3070  KABUPATEN CIREBON  0.8629  0.8  0.6667   0.7765
#
# [1 rows x 31 columns]

# %%
3290+1631+270+121
# Out:
# 5312

# %%
yourpath = "C:/Users/jwst2/Python/tesis/jpg/general desa spot ES/"
destpath = 'C:/Users/jwst2/Python/tesis/jpg/IDM/08. Desa SPOT 10m ES RES'

# %%
os.chdir(destpath)
if os.path.isdir('MAJU') is False:
    os.makedirs('MAJU MANDIRI')
    os.makedirs('TERTINGGAL BERKEMBANG')

# %%
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        if(not idm.status[idm.bps_kelurahan_kode == int(name.replace(".jpg",""))].empty):
            if(idm.status[idm.bps_kelurahan_kode == int(name.replace(".jpg",""))].iloc[0] == "MAJU"):
                shutil.copy(os.path.join(root, name), destpath+"/MAJU MANDIRI/"+name)
            elif(idm.status[idm.bps_kelurahan_kode == int(name.replace(".jpg",""))].iloc[0] == "BERKEMBANG"):
                shutil.copy(os.path.join(root, name), destpath+"/TERTINGGAL BERKEMBANG/"+name)
            elif(idm.status[idm.bps_kelurahan_kode == int(name.replace(".jpg",""))].iloc[0] == "TERTINGGAL"):
                shutil.copy(os.path.join(root, name), destpath+"/TERTINGGAL BERKEMBANG/"+name)
            elif(idm.status[idm.bps_kelurahan_kode == int(name.replace(".jpg",""))].iloc[0] == "MANDIRI"):
                shutil.copy(os.path.join(root, name), destpath+"/MAJU MANDIRI/"+name)
# Out:
# 1it [00:18, 18.64s/it]

# %%
1750+3052
# Out:
# 4802

# %% [markdown]
# #### Models

# %%
path = Path.cwd() / (destpath)

# %%
Path.BASE_PATH = path
path.ls()
# Out:
# (#3) [Path('MAJU MANDIRI'),Path('models'),Path('TERTINGGAL BERKEMBANG')]

# %%
fname = (path/"TERTINGGAL BERKEMBANG").ls()[0]
fname
# Out:
# Path('TERTINGGAL BERKEMBANG/3201010001.jpg')

# %%
img = Image.open(fname)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x277ECF02D30>

# %%
blocks = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, # finds the images in the path
                 splitter=RandomSplitter(0.1,seed=42),  # default random split 80% training, 20% validation
                 get_y=parent_label,
                 item_tfms = Resize(224)) # data augmentation (mult multiplies the default transformation values)

# %%
dls = blocks.dataloaders(path,bs= 10)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.show_batch(nrows=1, ncols=5)

# %% [markdown]
# #### Densenet

# %%
avg = 'macro'
roca = RocAucBinary(average=avg)
f1s = F1Score(average=avg)
bc = BalancedAccuracy()
metrics=[accuracy,bc, Precision(average=avg), Recall(average=avg), f1s,roca]

# %%
learn = cnn_learner(dls, densenet121, metrics=metrics)

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=9.999999747378752e-06)

# %%
learn.fit_one_cycle(7, lr_max = 1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.186005</td>
#       <td>0.927536</td>
#       <td>0.541667</td>
#       <td>0.582263</td>
#       <td>0.581111</td>
#       <td>0.582263</td>
#       <td>0.541595</td>
#       <td>0.610416</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.918311</td>
#       <td>0.760769</td>
#       <td>0.604167</td>
#       <td>0.574262</td>
#       <td>0.573555</td>
#       <td>0.574262</td>
#       <td>0.573864</td>
#       <td>0.624239</td>
#       <td>01:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.910020</td>
#       <td>0.694997</td>
#       <td>0.641667</td>
#       <td>0.624746</td>
#       <td>0.619710</td>
#       <td>0.624746</td>
#       <td>0.621034</td>
#       <td>0.673278</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.847195</td>
#       <td>0.771023</td>
#       <td>0.652083</td>
#       <td>0.611844</td>
#       <td>0.618213</td>
#       <td>0.611844</td>
#       <td>0.613871</td>
#       <td>0.638438</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.705633</td>
#       <td>0.688504</td>
#       <td>0.660417</td>
#       <td>0.605984</td>
#       <td>0.623428</td>
#       <td>0.605984</td>
#       <td>0.608359</td>
#       <td>0.664488</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.682251</td>
#       <td>0.695781</td>
#       <td>0.639583</td>
#       <td>0.602040</td>
#       <td>0.605785</td>
#       <td>0.602040</td>
#       <td>0.603391</td>
#       <td>0.662309</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.683674</td>
#       <td>0.695187</td>
#       <td>0.675000</td>
#       <td>0.616182</td>
#       <td>0.641634</td>
#       <td>0.616182</td>
#       <td>0.619017</td>
#       <td>0.664131</td>
#       <td>01:57</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2896: DecompressionBombWarning: Image size (170250304 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2896: DecompressionBombWarning: Image size (170250304 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2896: DecompressionBombWarning: Image size (170250304 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2896: DecompressionBombWarning: Image size (170250304 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2896: DecompressionBombWarning: Image size (170250304 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2896: DecompressionBombWarning: Image size (170250304 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
plt.plot(L(learn.recorder.values).itemgot(2));

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_top_losses(6, figsize=(15,11))

# %%
learn.export('C:/Users/jwst2/Python/tesis/idm/models/Desa densenet sentinel 10m ES RES.pkl')
