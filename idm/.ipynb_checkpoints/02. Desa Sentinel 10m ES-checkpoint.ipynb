# %% [markdown]
# # Desa Sentinel 10m ES

# %% [markdown]
# Kode modelling klasifikasi densenet dan resnet IDM pada data sentinel 2 10m dengan neighbor Square, input tingkat desa.

# %%
import fastai
from fastai.vision.all import *
import os
from PIL import Image
import pandas as pd
import shutil
import torch

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3050 Laptop GPU'

# %% [markdown]
# #### Preprocessing

# %%
idm = pd.read_csv("C:/Users/jwst2/Python/tesis/dataset/newdata_edit.csv")

# %%
idm = idm.drop_duplicates("bps_kelurahan_kode")

# %%
idm.groupby("status").count()
# Out:
#             kemendagri_kelurahan_kode  bps_kelurahan_kode  bps_kelurahan_nama  \
# status
# BERKEMBANG                       3290                3290                3223
# MAJU                             1631                1631                1584
# MANDIRI                           270                 270                 267
# TERTINGGAL                        121                 121                 119
#
#             kemendagri_kelurahan_nama    id  kemendagri_provinsi_kode  \
# status
# BERKEMBANG                       3290  3290                      3290
# MAJU                             1631  1631                      1631
# MANDIRI                           270   270                       270
# TERTINGGAL                        121   121                       121
#
#             kemendagri_kota_kode  kemendagri_kecamatan_kode  \
# status
# BERKEMBANG                  3290                       3290
# MAJU                        1631                       1631
# MANDIRI                      270                        270
# TERTINGGAL                   121                        121
#
#             kemendagri_provinsi_nama  kemendagri_kota_nama  ...  status_adm  \
# status                                                      ...
# BERKEMBANG                      3290                  3290  ...           0
# MAJU                            1631                  1631  ...           0
# MANDIRI                          270                   270  ...           0
# TERTINGGAL                       121                   121  ...           0
#
#             nama  id_kecamatan  nama_kecamatan  id_kabupaten  nama_kabupaten  \
# status
# BERKEMBANG  3290          3290            3290          3290            3290
# MAJU        1631          1631            1631          1631            1631
# MANDIRI      270           270             270           270             270
# TERTINGGAL   121           121             121           121             121
#
#              iks   ike   ikl  avg_idm
# status
# BERKEMBANG  3290  3290  3290     3290
# MAJU        1631  1631  1631     1631
# MANDIRI      270   270   270      270
# TERTINGGAL   121   121   121      121
#
# [4 rows x 30 columns]

# %%
idm[idm.bps_kelurahan_kode ==3209100011]
# Out:
#       kemendagri_kelurahan_kode  bps_kelurahan_kode status bps_kelurahan_nama  \
# 3070                 3209132011        3.209100e+09   MAJU                NaN
#
#      kemendagri_kelurahan_nama    id  kemendagri_provinsi_kode  \
# 3070                     BEBER  3038                        32
#
#       kemendagri_kota_kode kemendagri_kecamatan_kode kemendagri_provinsi_nama  \
# 3070                 32.09                  32.09.13               JAWA BARAT
#
#       ... status_adm   nama  id_kecamatan  nama_kecamatan  id_kabupaten  \
# 3070  ...        NaN  BEBER      320913.0           BEBER        3209.0
#
#          nama_kabupaten     iks  ike     ikl  avg_idm
# 3070  KABUPATEN CIREBON  0.8629  0.8  0.6667   0.7765
#
# [1 rows x 31 columns]

# %%
3290+1631+270+121
# Out:
# 5312

# %%
os.chdir('C:/Users/jwst2/Python/tesis/jpg/IDM/02. Desa Sentinel 10m ES')
if os.path.isdir('jabar_idm/MAJU') is False:
    os.makedirs('MAJU MANDIRI')
    os.makedirs('TERTINGGAL BERKEMBANG')

# %%
yourpath = "C:/Users/jwst2/Python/tesis/jpg/general desa sentinel ES/"
destpath = 'C:/Users/jwst2/Python/tesis/jpg/IDM/02. Desa Sentinel 10m ES'

# %%
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        if(not idm.status[idm.bps_kelurahan_kode == int(name.replace(".jpg",""))].empty):
            if(idm.status[idm.bps_kelurahan_kode == int(name.replace(".jpg",""))].iloc[0] == "MAJU"):
                shutil.copy(os.path.join(root, name), destpath+"/MAJU MANDIRI/"+name)
            elif(idm.status[idm.bps_kelurahan_kode == int(name.replace(".jpg",""))].iloc[0] == "BERKEMBANG"):
                shutil.copy(os.path.join(root, name), destpath+"/TERTINGGAL BERKEMBANG/"+name)
            elif(idm.status[idm.bps_kelurahan_kode == int(name.replace(".jpg",""))].iloc[0] == "TERTINGGAL"):
                shutil.copy(os.path.join(root, name), destpath+"/TERTINGGAL BERKEMBANG/"+name)
            elif(idm.status[idm.bps_kelurahan_kode == int(name.replace(".jpg",""))].iloc[0] == "MANDIRI"):
                shutil.copy(os.path.join(root, name), destpath+"/MAJU MANDIRI/"+name)
# Out:
# 1it [00:20, 20.66s/it]

# %% [markdown]
# #### Models

# %%
path = Path.cwd() / (destpath)

# %%
Path.BASE_PATH = path
path.ls()
# Out:
# (#2) [Path('MAJU MANDIRI'),Path('TERTINGGAL BERKEMBANG')]

# %%
fname = (path/"TERTINGGAL BERKEMBANG").ls()[0]
fname
# Out:
# Path('TERTINGGAL BERKEMBANG/3201010001.jpg')

# %%
img = Image.open(fname)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x2AF2ECDBA90>

# %%
blocks = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, # finds the images in the path
                 splitter=RandomSplitter(0.1,seed=42),  # default random split 80% training, 20% validation
                 get_y=parent_label) # data augmentation (mult multiplies the default transformation values)

# %%
dls = blocks.dataloaders(path,bs= 10)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.show_batch(nrows=1, ncols=5)

# %% [markdown]
# #### Densenet

# %%
avg = 'macro'
roca = RocAucBinary(average=avg)
f1s = F1Score(average=avg)
bc = BalancedAccuracy()
metrics=[accuracy,bc, Precision(average=avg), Recall(average=avg), f1s,roca]

# %%
learn = cnn_learner(dls, densenet121, metrics=metrics)
# Out:
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\fastai\vision\learner.py:265: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0005754399462603033)

# %%
learn.fit_one_cycle(5, lr_max = 1e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.989277</td>
#       <td>0.850134</td>
#       <td>0.615819</td>
#       <td>0.594373</td>
#       <td>0.587893</td>
#       <td>0.594373</td>
#       <td>0.588422</td>
#       <td>0.597974</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.853786</td>
#       <td>0.909133</td>
#       <td>0.613936</td>
#       <td>0.567236</td>
#       <td>0.567797</td>
#       <td>0.567236</td>
#       <td>0.567495</td>
#       <td>0.622555</td>
#       <td>01:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.721600</td>
#       <td>0.611530</td>
#       <td>0.683616</td>
#       <td>0.634829</td>
#       <td>0.642502</td>
#       <td>0.634829</td>
#       <td>0.637719</td>
#       <td>0.684362</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.610617</td>
#       <td>0.581178</td>
#       <td>0.704331</td>
#       <td>0.603134</td>
#       <td>0.678765</td>
#       <td>0.603134</td>
#       <td>0.601231</td>
#       <td>0.702928</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.579219</td>
#       <td>0.579185</td>
#       <td>0.721281</td>
#       <td>0.649786</td>
#       <td>0.689657</td>
#       <td>0.649786</td>
#       <td>0.657598</td>
#       <td>0.710557</td>
#       <td>01:56</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(1, lr_max = 1e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.613275</td>
#       <td>0.586443</td>
#       <td>0.725047</td>
#       <td>0.655342</td>
#       <td>0.694470</td>
#       <td>0.655342</td>
#       <td>0.663562</td>
#       <td>0.706062</td>
#       <td>01:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.plot(L(learn.recorder.values).itemgot(2));

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_top_losses(6, figsize=(15,11))

# %%
learn.export('C:/Users/jwst2/Python/tesis/idm/models/Desa densenet sentinel 10m ES.pkl')

# %% [markdown]
# #### Resnet

# %%
learn_rs = cnn_learner(dls, resnet50, metrics=metrics)
# Out:
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\fastai\vision\learner.py:265: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")

# %%
learn_rs.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0004786300996784121)

# %%
learn_rs.fit_one_cycle(5, lr_max = 1e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.079857</td>
#       <td>1.107240</td>
#       <td>0.499058</td>
#       <td>0.545299</td>
#       <td>0.543497</td>
#       <td>0.545299</td>
#       <td>0.498544</td>
#       <td>0.571985</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.028472</td>
#       <td>0.654164</td>
#       <td>0.644068</td>
#       <td>0.544017</td>
#       <td>0.568272</td>
#       <td>0.544017</td>
#       <td>0.534074</td>
#       <td>0.597974</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.768884</td>
#       <td>0.643538</td>
#       <td>0.659134</td>
#       <td>0.573006</td>
#       <td>0.598938</td>
#       <td>0.573006</td>
#       <td>0.571623</td>
#       <td>0.613406</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.672678</td>
#       <td>0.618835</td>
#       <td>0.677966</td>
#       <td>0.548006</td>
#       <td>0.644539</td>
#       <td>0.548006</td>
#       <td>0.514685</td>
#       <td>0.673678</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.614041</td>
#       <td>0.581758</td>
#       <td>0.706215</td>
#       <td>0.611325</td>
#       <td>0.677211</td>
#       <td>0.611325</td>
#       <td>0.612626</td>
#       <td>0.705492</td>
#       <td>01:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_rs.fit_one_cycle(1, lr_max = 1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.609886</td>
#       <td>0.577554</td>
#       <td>0.706215</td>
#       <td>0.616738</td>
#       <td>0.673811</td>
#       <td>0.616738</td>
#       <td>0.619935</td>
#       <td>0.706964</td>
#       <td>01:42</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.plot(L(learn_rs.recorder.values).itemgot(2));

# %%
interp = ClassificationInterpretation.from_learner(learn_rs)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn_rs.export('C:/Users/jwst2/Python/tesis/idm/models/Desa resnet sentinel 10m ES.pkl')

# %%
interp.plot_top_losses(16, figsize=(15,11))
