# %%
import fastai
from fastai.vision.all import *
import pandas as pd

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,roc_auc_score,balanced_accuracy_score
import numpy as np

# %%
sls = pd.read_csv("C:/Users/jwst2/Python/tesis/dataset/3200_sls.csv")
# Out:
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sls.head()
# Out:
#        id  kdprov  kdkab  kdkec  kddesa      iddesa  idslsnon  \
# 0  263884      32      1     10       1  3201010001       100
# 1  263885      32      1     10       1  3201010001       200
# 2  263886      32      1     10       1  3201010001       300
# 3  263887      32      1     10       1  3201010001       400
# 4  263888      32      1     10       1  3201010001       500
#
#                 nmslsnon              ketua_sls  jenis  ...  j_bstt  j_bsbtt  \
# 0  RT 001 RW 001 DUSUN 1  MUHAMAD RAFLI HIDAYAT      1  ...      39        1
# 1  RT 002 RW 001 DUSUN 1                 NURMAN      1  ...      60        2
# 2  RT 003 RW 001 DUSUN 1               SAENUDIN      1  ...      50        2
# 3  RT 004 RW 001 DUSUN 1                    AEP      1  ...      27        1
# 4  RT 005 RW 001 DUSUN 1          JEJEN JAELANI      1  ...      49        7
#
#    j_bstt_k  j_bskeko  j_segmen  dom  ldom  j_m_all j_m_30 klas_ur
# 0         2         4         1    1     1       51     51       2
# 1         0         7         1    1     1       62     61       2
# 2         0         6         1    1     1       58     57       2
# 3         0         1         1    1     1       31     31       2
# 4         3         8         3    1     1       63     57       2
#
# [5 rows x 36 columns]

# %%
sls.iddesa.unique().shape
# Out:
# (5957,)

# %%
ur_path = "C:/Users/jwst2/Python/tesis/jpg/UR/05. Spot SLS ES"
gen_path =  "C:/Users/jwst2/Python/tesis/jpg/general sls spot ES/"
test_path = 'C:/Users/jwst2/Python/tesis/jpg/UR/test sls spot ES/'
model_code_resnet = "R005"
model_code_dense = "D005"

# %%
os.chdir(ur_path)
if os.path.isdir('urban') is False:
    os.makedirs('urban')
    os.makedirs('rural')

# %%
yourpath = "C:/Users/jwst2/Python/tesis/jpg/general sls spot ES/"
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        try :
            if(sls.klas_ur[sls.iddesa == int(name.replace(".jpg","")[:10])].iloc[0] == 1):
                shutil.copy(os.path.join(root, name), ur_path+"/urban/"+name)
            elif(sls.klas_ur[sls.iddesa == int(name.replace(".jpg","")[:10])].iloc[0] == 2):
                shutil.copy(os.path.join(root, name),ur_path+ "/rural/"+name)
        except Exception:
            print(name)
            pass
# Out:
# 0it [00:00, ?it/s]
# 32070000002000.jpg
# 32080000002001.jpg
# 32080100006001.jpg
# 32170000006001.jpg
# 1it [16:43, 1003.76s/it]

# %%
split = pd.read_csv("C:/Users/jwst2/Python/tesis/dataset/datasplit_ur_desa.csv")

# %%
split_test =split

# %%
split_test
# Out:
#      Unnamed: 0      iddesa
# 0             0  3207250012
# 1             1  3273111002
# 2             2  3205260016
# 3             3  3212030010
# 4             4  3208181004
# ..          ...         ...
# 590         590  3210070009
# 591         591  3209040007
# 592         592  3203051007
# 593         593  3208030017
# 594         594  3209181004
#
# [595 rows x 2 columns]

# %% [markdown]
# ### Create test

# %%
os.chdir(test_path)
if os.path.isdir('urban') is False:
    os.makedirs('urban')
    os.makedirs('rural')

# %%
yourpath = ur_path+ "/rural"
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        try :
            if(split_test.iddesa.astype(str).str.contains(name[:10]).sum() > 0):
                shutil.move(os.path.join(root, name),test_path + "/rural/"+name)
        except Exception:
            print(name)
            pass
# Out:
# 1it [00:38, 38.59s/it]

# %%
yourpath =  ur_path+ "/urban"
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        try :
            if(split_test.iddesa.astype(str).str.contains(name[:10]).sum() > 0):
                shutil.move(os.path.join(root, name), test_path +"/urban/"+name)
        except Exception:
            print(name)
            pass
# Out:
# 1it [02:15, 135.14s/it]

# %% [markdown]
# ### Run Dataset

# %%
path = Path.cwd() / (ur_path)

# %%
Path.BASE_PATH = path
path.ls()
# Out:
# (#2) [Path('rural'),Path('urban')]

# %%
fname = (path/"rural").ls()[0]
fname
# Out:
# Path('rural/32010100010001.jpg')

# %%
img = Image.open(fname)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=721x721 at 0x255E789C190>

# %%
blocks = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, # finds the images in the path
                 splitter=RandomSplitter(valid_pct=0.1, seed=42),  # default random split 80% training, 20% validation
                 get_y=parent_label # extracts the label category from the image's folder name 
                 ,item_tfms = Resize(128)) # data augmentation (mult multiplies the default transformation values)

# %%
dls = blocks.dataloaders(path, bs =5)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.show_batch(nrows=1, ncols=5)

# %%
avg = 'macro'
roca = RocAucBinary(average=avg)
f1s = F1Score(average=avg)
bc = BalancedAccuracy()
metrics=[accuracy,bc, Precision(average=avg), Recall(average=avg), f1s, roca]
learn = cnn_learner(dls, densenet121, metrics=metrics)

# %%
learn.fit_one_cycle(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.410846</td>
#       <td>0.381579</td>
#       <td>0.821398</td>
#       <td>0.628479</td>
#       <td>0.761454</td>
#       <td>0.628479</td>
#       <td>0.652775</td>
#       <td>0.846767</td>
#       <td>1:46:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.415586</td>
#       <td>0.379995</td>
#       <td>0.816597</td>
#       <td>0.594035</td>
#       <td>0.785071</td>
#       <td>0.594035</td>
#       <td>0.608994</td>
#       <td>0.850830</td>
#       <td>1:46:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.382538</td>
#       <td>0.366459</td>
#       <td>0.821600</td>
#       <td>0.617680</td>
#       <td>0.775523</td>
#       <td>0.617680</td>
#       <td>0.640446</td>
#       <td>0.859925</td>
#       <td>1:43:36</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5)

# %%
learn.fit_one_cycle(5)

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.324816</td>
#       <td>0.343184</td>
#       <td>0.831404</td>
#       <td>0.710113</td>
#       <td>0.751467</td>
#       <td>0.710113</td>
#       <td>0.726599</td>
#       <td>0.875955</td>
#       <td>26:12</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
dls.vocab
# Out:
# ['rural', 'urban']

# %%
dls.train.items[175000]
# Out:
# Path('urban/32100900170013.jpg')

# %%
learn.export("C:/Users/jwst2/Python/tesis/models/19042022"+ model_code_dense+".pkl")

# %% [markdown]
# ### Up level

# %%
idx_train = []
for i in dls.train.items:
    idx_train.append(str(i)[-18:-4])
true_label = []
for i in dls.train.items:
    if("urban" in str(i)) :
        true_label.append(1)
    else :
        true_label.append(0)

# %%
preds,_ = learn.get_preds(ds_idx  = 0)
result_train = preds.numpy()
new_train = pd.DataFrame(result_train)

# %%
pd.value_counts(true_label)
# Out:
# 1    140272
# 0     37820
# dtype: int64

# %%
df = new_train
df["idsls"] = idx_train 
df["stat"] = round(df[1])
df["iddesa"] = df.idsls.str[:10]
df.head()
# Out:
#           0         1           idsls  stat      iddesa
# 0  0.000447  0.999553  32731000020061   1.0  3273100002
# 1  0.001145  0.998855  32150500070004   1.0  3215050007
# 2  0.589724  0.410276  32022100131006   0.0  3202210013
# 3  0.151474  0.848526  32081500110025   1.0  3208150011
# 4  0.165433  0.834567  32110500010021   1.0  3211050001

# %%
pd.value_counts(df.stat)
# Out:
# 1.0    147125
# 0.0     30967
# Name: stat, dtype: int64

# %%
df["true_lab"] = true_label

# %%
pd.value_counts(df.true_lab)
# Out:
# 1    140272
# 0     37820
# Name: true_lab, dtype: int64

# %%
accuracy_score(df.stat.apply(int),df.true_lab.apply(int))
# Out:
# 0.8521269905442131

# %%
df.head()
# Out:
#           0         1           idsls  stat      iddesa  true_lab
# 0  0.000447  0.999553  32731000020061   1.0  3273100002         1
# 1  0.001145  0.998855  32150500070004   1.0  3215050007         1
# 2  0.589724  0.410276  32022100131006   0.0  3202210013         1
# 3  0.151474  0.848526  32081500110025   1.0  3208150011         1
# 4  0.165433  0.834567  32110500010021   1.0  3211050001         1

# %%
desa_pred = df.groupby('iddesa').agg({'stat': ['mean'], 'true_lab': 'mean'})

# %%
desa_pred.columns = ["pred","true"]

# %%
pd.value_counts(df.stat)
# Out:
# 1.0    147125
# 0.0     30967
# Name: stat, dtype: int64

# %%
for i in np.arange(0.1, 0.95, 0.05):
    value = round(i,2)
    desa_pred["label"+str(value)] = 0
    desa_pred["label"+str(value)][desa_pred.pred > value] = 1
# Out:
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_34804/4109382162.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred["label"+str(value)][desa_pred.pred > value] = 1

# %%
desa_pred.head()
# Out:
#                 pred  true  label0.1  label0.15  label0.2  label0.25  \
# iddesa
# 3201010001  0.224138   0.0         1          1         1          0
# 3201010002  0.695652   0.0         1          1         1          1
# 3201010003  0.552632   1.0         1          1         1          1
# 3201010004  0.604167   0.0         1          1         1          1
# 3201010005  0.433333   1.0         1          1         1          1
#
#             label0.3  label0.35  label0.4  label0.45  label0.5  label0.55  \
# iddesa
# 3201010001         0          0         0          0         0          0
# 3201010002         1          1         1          1         1          1
# 3201010003         1          1         1          1         1          1
# 3201010004         1          1         1          1         1          1
# 3201010005         1          1         1          0         0          0
#
#             label0.6  label0.65  label0.7  label0.75  label0.8  label0.85  \
# iddesa
# 3201010001         0          0         0          0         0          0
# 3201010002         1          1         0          0         0          0
# 3201010003         0          0         0          0         0          0
# 3201010004         1          0         0          0         0          0
# 3201010005         0          0         0          0         0          0
#
#             label0.9
# iddesa
# 3201010001         0
# 3201010002         0
# 3201010003         0
# 3201010004         0
# 3201010005         0

# %%
for j in range(2,19):
    print("result", desa_pred.columns[j])
    print("accuracy :",  accuracy_score( desa_pred.true,desa_pred.iloc[:,[j]]))
    print("precision :",  precision_score( desa_pred.true,desa_pred.iloc[:,[j]]))
# Out:
# result label0.1
# accuracy : 0.768183513614323
# precision : 0.7594386242340383
# result label0.15
# accuracy : 0.7795598657217456
# precision : 0.769895498392283
# result label0.2
# accuracy : 0.7905632226781052
# precision : 0.7805027590435316
# result label0.25
# accuracy : 0.8011935844834017
# precision : 0.7906639004149377
# result label0.3
# accuracy : 0.8069750093248788
# precision : 0.7977717048560017
# result label0.35
# accuracy : 0.8204028347631481
# precision : 0.8113612004287245
# result label0.4
# accuracy : 0.829727713539724
# precision : 0.8230920621036518
# result label0.45
# accuracy : 0.8373741141365162
# precision : 0.8330369052912405
# result label0.5
# accuracy : 0.8498694516971279
# precision : 0.8494182067077344
# result label0.55
# accuracy : 0.8554643789630735
# precision : 0.859400418312805
# result label0.6
# accuracy : 0.8573293547183887
# precision : 0.8700214643453374
# result label0.65
# accuracy : 0.8621782916822082
# precision : 0.8852499384388082
# result label0.7
# accuracy : 0.8593808280492353
# precision : 0.8961832061068702
# result label0.75
# accuracy : 0.8565833644162626
# precision : 0.9100291082296904
# result label0.8
# accuracy : 0.8508019395747856
# precision : 0.9258745141588006
# result label0.85
# accuracy : 0.835136143230138
# precision : 0.9406379208505611
# result label0.9
# accuracy : 0.7998881014546811
# precision : 0.959250739401906

# %%
pd.value_counts(desa_pred.true)
# Out:
# 1.0    3868
# 0.0    1494
# Name: true, dtype: int64

# %% [markdown]
# ### Test result

# %%
path_pred = Path.cwd() / (test_path)
test_files = [fn for fn in sorted((path_pred).glob('**/*')) if fn.is_file()]

# %%
len(test_files)
# Out:
# 22054

# %%
test_dl = learn.dls.test_dl(test_files)

# %%
preds,_ = learn.get_preds(dl  =test_dl)

# %%
str(test_files[1])[-18:-4]
# Out:
# '32011500010002'

# %%
idx_test = []
for i in test_files:
    idx_test.append(str(i)[-18:-4])
true_label = []
for i in test_files:
    if("urban" in str(i)) :
        true_label.append(1)
    else :
        true_label.append(0)

# %%
test = pd.DataFrame(preds)

# %%
test["idsls"] = idx_test
test["true_lab"] = true_label

# %%
test["iddesa"] = test.idsls.str[:10]
test["stat"] = round(test[1])

# %%
test.head()
# Out:
#           0         1           idsls  true_lab      iddesa  stat
# 0  0.810315  0.189685  32011500010001         0  3201150001   0.0
# 1  0.828003  0.171997  32011500010002         0  3201150001   0.0
# 2  0.811717  0.188283  32011500010003         0  3201150001   0.0
# 3  0.718211  0.281789  32011500010004         0  3201150001   0.0
# 4  0.728505  0.271495  32011500010005         0  3201150001   0.0

# %%
desa_pred_test = test.groupby('iddesa').agg({'stat': ['mean'], 'true_lab': 'mean'})

# %%
desa_pred_test
# Out:
#                 stat true_lab
#                 mean     mean
# iddesa
# 3201010010  0.628571      1.0
# 3201040001  1.000000      1.0
# 3201040005  1.000000      1.0
# 3201050012  1.000000      1.0
# 3201050013  1.000000      1.0
# ...              ...      ...
# 3278050003  1.000000      1.0
# 3278071005  0.975000      1.0
# 3278080002  0.944444      1.0
# 3279010006  0.979798      1.0
# 3279030005  1.000000      1.0
#
# [595 rows x 2 columns]

# %%
desa_pred_test.columns = ["pred","true"]

# %%
desa_pred_test["pred_lab"] = 0
desa_pred_test["pred_lab"][desa_pred_test.pred > 0.675] = 1
# Out:
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_34804/1982971506.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred_test["pred_lab"][desa_pred_test.pred > 0.675] = 1

# %%
print("accuracy :",  accuracy_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("balanced_accuracy_score :",  balanced_accuracy_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("precision :",  precision_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("recall :",  recall_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("f1 :",  f1_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("rocauc :",  roc_auc_score( desa_pred_test.true,desa_pred_test.pred_lab))
# Out:
# accuracy : 0.8252100840336134
# balanced_accuracy_score : 0.7608801717408276
# precision : 0.8565121412803532
# recall : 0.9086651053864169
# f1 : 0.881818181818182
# rocauc : 0.7608801717408276

# %% [markdown]
# ### Resnet

# %%
learn_rs = cnn_learner(dls, resnet50, metrics=metrics)

# %%
learn_rs.fit_one_cycle(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.392389</td>
#       <td>0.383353</td>
#       <td>0.817203</td>
#       <td>0.623907</td>
#       <td>0.747309</td>
#       <td>0.623907</td>
#       <td>0.646505</td>
#       <td>0.837134</td>
#       <td>20:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.366825</td>
#       <td>0.358194</td>
#       <td>0.823874</td>
#       <td>0.638464</td>
#       <td>0.762776</td>
#       <td>0.638464</td>
#       <td>0.664222</td>
#       <td>0.862533</td>
#       <td>22:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.355325</td>
#       <td>0.352786</td>
#       <td>0.825694</td>
#       <td>0.681682</td>
#       <td>0.745385</td>
#       <td>0.681682</td>
#       <td>0.703257</td>
#       <td>0.866116</td>
#       <td>18:52</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
learn_rs.unfreeze()

# %%
learn_rs.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.375521</td>
#       <td>0.417571</td>
#       <td>0.816294</td>
#       <td>0.598266</td>
#       <td>0.774133</td>
#       <td>0.598266</td>
#       <td>0.614854</td>
#       <td>0.823523</td>
#       <td>20:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.379149</td>
#       <td>0.410677</td>
#       <td>0.797695</td>
#       <td>0.528781</td>
#       <td>0.815501</td>
#       <td>0.528781</td>
#       <td>0.499610</td>
#       <td>0.845004</td>
#       <td>20:48</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.383252</td>
#       <td>0.373494</td>
#       <td>0.820488</td>
#       <td>0.638656</td>
#       <td>0.749342</td>
#       <td>0.638656</td>
#       <td>0.663158</td>
#       <td>0.851458</td>
#       <td>24:56</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.374101</td>
#       <td>0.365508</td>
#       <td>0.818163</td>
#       <td>0.719743</td>
#       <td>0.727869</td>
#       <td>0.719743</td>
#       <td>0.723618</td>
#       <td>0.859629</td>
#       <td>21:37</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.346560</td>
#       <td>0.359920</td>
#       <td>0.821297</td>
#       <td>0.613064</td>
#       <td>0.780911</td>
#       <td>0.613064</td>
#       <td>0.634748</td>
#       <td>0.865127</td>
#       <td>20:44</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.344061</td>
#       <td>0.350989</td>
#       <td>0.829535</td>
#       <td>0.683774</td>
#       <td>0.754434</td>
#       <td>0.683774</td>
#       <td>0.707067</td>
#       <td>0.868733</td>
#       <td>20:55</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.321731</td>
#       <td>0.351484</td>
#       <td>0.826704</td>
#       <td>0.713546</td>
#       <td>0.741859</td>
#       <td>0.713546</td>
#       <td>0.725622</td>
#       <td>0.870683</td>
#       <td>20:28</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.300516</td>
#       <td>0.354546</td>
#       <td>0.826704</td>
#       <td>0.678508</td>
#       <td>0.748940</td>
#       <td>0.678508</td>
#       <td>0.701398</td>
#       <td>0.870332</td>
#       <td>20:58</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.282004</td>
#       <td>0.371418</td>
#       <td>0.821752</td>
#       <td>0.719680</td>
#       <td>0.733293</td>
#       <td>0.719680</td>
#       <td>0.725977</td>
#       <td>0.865276</td>
#       <td>22:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.258623</td>
#       <td>0.388672</td>
#       <td>0.821095</td>
#       <td>0.705473</td>
#       <td>0.732361</td>
#       <td>0.705473</td>
#       <td>0.716933</td>
#       <td>0.862063</td>
#       <td>22:01</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
learn_rs.export("C:/Users/jwst2/Python/tesis/models/19042022"+ model_code_resnet+".pkl")

# %%
idx_train = []
for i in dls.train.items:
    idx_train.append(str(i)[-18:-4])
true_label = []
for i in dls.train.items:
    if("urban" in str(i)) :
        true_label.append(1)
    else :
        true_label.append(0)

# %%
preds,_ = learn_rs.get_preds(ds_idx  = 0)
result_train = preds.numpy()
new_train = pd.DataFrame(result_train)
# Out:
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
df = new_train
df["idsls"] = idx_train 
df["stat"] = round(df[1])
df["iddesa"] = df.idsls.str[:10]
df.head()
# Out:
#           0         1           idsls  stat      iddesa  true_lab
# 0  0.000015  0.999985  32731000020061   1.0  3273100002         1
# 1  0.000002  0.999998  32150500070004   1.0  3215050007         1
# 2  0.350874  0.649126  32022100131006   1.0  3202210013         1
# 3  0.167167  0.832833  32081500110025   1.0  3208150011         1
# 4  0.014394  0.985606  32110500010021   1.0  3211050001         1

# %%
pd.value_counts(df.stat)
# Out:
# 1.0    143403
# 0.0     34689
# Name: stat, dtype: int64

# %%
df["true_lab"] = true_label
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34804/1665248022.py in <module>
# ----> 1 df["true_lab"] = true_label
#
# ~\anaconda3\envs\datasc\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\envs\datasc\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\anaconda3\envs\datasc\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# ~\anaconda3\envs\datasc\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (22054) does not match length of index (178092)

# %%
pd.value_counts(df.true_lab)

# %%
accuracy_score(df.stat.apply(int),df.true_lab.apply(int))

# %%
df.head()

# %%
desa_pred = df.groupby('iddesa').agg({'stat': ['mean'], 'true_lab': 'mean'})

# %%
desa_pred.columns = ["pred","true"]

# %%
pd.value_counts(df.stat)
# Out:
# 1.0    143403
# 0.0     34689
# Name: stat, dtype: int64

# %%
for i in np.arange(0.1, 0.95, 0.025):
    value = round(i,2)
    desa_pred["label"+str(value)] = 0
    desa_pred["label"+str(value)][desa_pred.pred > value] = 1
# Out:
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_34804/935834860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred["label"+str(value)][desa_pred.pred > value] = 1

# %%
desa_pred.head()
# Out:
#                 pred  true  label0.1  label0.12  label0.15  label0.18  \
# iddesa
# 3201010001  0.155172   0.0         1          1          1          0
# 3201010002  0.543478   0.0         1          1          1          1
# 3201010003  0.710526   1.0         1          1          1          1
# 3201010004  0.479167   0.0         1          1          1          1
# 3201010005  0.666667   1.0         1          1          1          1
#
#             label0.2  label0.22  label0.25  label0.27  ...  label0.7  \
# iddesa                                                 ...
# 3201010001         0          0          0          0  ...         0
# 3201010002         1          1          1          1  ...         0
# 3201010003         1          1          1          1  ...         1
# 3201010004         1          1          1          1  ...         0
# 3201010005         1          1          1          1  ...         0
#
#             label0.72  label0.75  label0.77  label0.8  label0.82  label0.85  \
# iddesa
# 3201010001          0          0          0         0          0          0
# 3201010002          0          0          0         0          0          0
# 3201010003          0          0          0         0          0          0
# 3201010004          0          0          0         0          0          0
# 3201010005          0          0          0         0          0          0
#
#             label0.87  label0.9  label0.92
# iddesa
# 3201010001          0         0          0
# 3201010002          0         0          0
# 3201010003          0         0          0
# 3201010004          0         0          0
# 3201010005          0         0          0
#
# [5 rows x 36 columns]

# %%
for j in range(2,36):
    print("result", desa_pred.columns[j])
    print("accuracy :",  accuracy_score( desa_pred.true,desa_pred.iloc[:,[j]]))
    print("precision :",  precision_score( desa_pred.true,desa_pred.iloc[:,[j]]))
# Out:
# result label0.1
# accuracy : 0.7720999627004849
# precision : 0.761049723756906
# result label0.12
# accuracy : 0.779373368146214
# precision : 0.7669516802545238
# result label0.15
# accuracy : 0.7954121596419247
# precision : 0.7804088241246712
# result label0.18
# accuracy : 0.8086534875046625
# precision : 0.7917864476386037
# result label0.2
# accuracy : 0.819283849309959
# precision : 0.8012887133652047
# result label0.22
# accuracy : 0.8273032450578143
# precision : 0.808515100671141
# result label0.25
# accuracy : 0.8476314807907497
# precision : 0.8282763072950291
# result label0.27
# accuracy : 0.8554643789630735
# precision : 0.8358306188925081
# result label0.3
# accuracy : 0.8685192092502797
# precision : 0.8491940825789357
# result label0.32
# accuracy : 0.8778440880268557
# precision : 0.8596373404969778
# result label0.35
# accuracy : 0.8881014546810891
# precision : 0.8710263396911898
# result label0.37
# accuracy : 0.8953748601268183
# precision : 0.879678530424799
# result label0.4
# accuracy : 0.9102946661693399
# precision : 0.8976285513031228
# result label0.42
# accuracy : 0.9151436031331592
# precision : 0.9042880833925611
# result label0.45
# accuracy : 0.9233494964565461
# precision : 0.9166064111834177
# result label0.47
# accuracy : 0.9270794479671765
# precision : 0.9218636253336568
# result label0.5
# accuracy : 0.9360313315926893
# precision : 0.9370195883957352
# result label0.52
# accuracy : 0.9365908243192839
# precision : 0.9383697813121272
# result label0.55
# accuracy : 0.9403207758299142
# precision : 0.9468513853904282
# result label0.57
# accuracy : 0.9429317418873555
# precision : 0.9538735983690112
# result label0.6
# accuracy : 0.9470346885490488
# precision : 0.9632885211995863
# result label0.62
# accuracy : 0.9490861618798956
# precision : 0.9674902470741222
# result label0.65
# accuracy : 0.9470346885490488
# precision : 0.9725738396624473
# result label0.67
# accuracy : 0.9461022006713913
# precision : 0.9770727805918422
# result label0.7
# accuracy : 0.9414397612831034
# precision : 0.9802702702702702
# result label0.72
# accuracy : 0.9375233121969414
# precision : 0.9825184375853592
# result label0.75
# accuracy : 0.9257739649384558
# precision : 0.9849077697037452
# result label0.77
# accuracy : 0.9216710182767625
# precision : 0.9878324844368988
# result label0.8
# accuracy : 0.9052592316299888
# precision : 0.9900816802800467
# result label0.82
# accuracy : 0.8948153674002238
# precision : 0.9913741820345032
# result label0.85
# accuracy : 0.8701976874300634
# precision : 0.9931592039800995
# result label0.87
# accuracy : 0.8562103692651996
# precision : 0.9948865452221157
# result label0.9
# accuracy : 0.825065274151436
# precision : 0.9966101694915255
# result label0.92
# accuracy : 0.798023125699366
# precision : 0.9967891544773457

# %% [markdown]
# ### Test result resnet

# %%
path_pred = Path.cwd() / (test_path)
test_files = [fn for fn in sorted((path_pred).glob('**/*')) if fn.is_file()]

# %%
test_dl = learn_rs.dls.test_dl(test_files)

# %%
preds,_ = learn_rs.get_preds(dl  =test_dl)

# %%
idx_test = []
for i in test_files:
    idx_test.append(str(i)[-18:-4])
true_label = []
for i in test_files:
    if("urban" in str(i)) :
        true_label.append(1)
    else :
        true_label.append(0)

# %%
test = pd.DataFrame(preds)

# %%
test["idsls"] = idx_test
test["true_lab"] = true_label

# %%
test["iddesa"] = test.idsls.str[:10]
test["stat"] = round(test[1])

# %%
test.head()
# Out:
#           0         1           idsls  true_lab      iddesa  stat
# 0  0.834452  0.165548  32011500010001         0  3201150001   0.0
# 1  0.811685  0.188315  32011500010002         0  3201150001   0.0
# 2  0.605605  0.394395  32011500010003         0  3201150001   0.0
# 3  0.361632  0.638368  32011500010004         0  3201150001   1.0
# 4  0.432751  0.567249  32011500010005         0  3201150001   1.0

# %%
desa_pred_test = test.groupby('iddesa').agg({'stat': ['mean'], 'true_lab': 'mean'})

# %%
desa_pred_test.columns = ["pred","true"]

# %%
desa_pred_test["pred_lab"] = 0
desa_pred_test["pred_lab"][desa_pred_test.pred > 0.625] = 1
# Out:
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_34804/1214450167.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred_test["pred_lab"][desa_pred_test.pred > 0.625] = 1

# %%
print("accuracy :",  accuracy_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("balanced_accuracy_score :",  balanced_accuracy_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("precision :",  precision_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("recall :",  recall_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("f1 :",  f1_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("rocauc :",  roc_auc_score( desa_pred_test.true,desa_pred_test.pred_lab))
# Out:
# accuracy : 0.8285714285714286
# balanced_accuracy_score : 0.7560011709601874
# precision : 0.8509719222462203
# recall : 0.9227166276346604
# f1 : 0.8853932584269663
# rocauc : 0.7560011709601874

# %%
accuracy : 0.8117647058823529
balanced_accuracy_score : 0.7623438719750195
precision : 0.8637413394919169
recall : 0.8758782201405152
f1 : 0.8697674418604651
rocauc : 0.7623438719750195
