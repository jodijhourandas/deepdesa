# %% [markdown]
# # UR Desa Comparison SentinelXSPOT

# %% [markdown]
# Dari hasil sebelumnya, dapat dilihat densenet121 adalah model terbaik untuk mengklasfikari desa urban dan rural dengan model data : SLS dan Square Neighbour. Skenario tersebut akan digunakan untuk menguji efek resolusi terhadap klasifikasi dengan melakukan train terhadapa uncovered desa baik dengan data sentinel maupun spot.
#
# Pada proses clipping citra , ditemukan 577 desa dengan tutupan awan tinggi untuk satelit SPOT 6-7 seperti yang dapat dilihat pada Gambar 6. Sehingga pada kajian efek resolusi citra terhadap model akan dilakukan pada 5380 desa dan 200.200 SLS.

# %% [markdown]
# ![image.png](attachment:ae457814-125e-48cf-9dd3-99ef3d83576f.png)

# %% [markdown]
# #### Import Fast AI

# %%
import fastai
from fastai.vision.all import *
import pandas as pd

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,roc_auc_score,balanced_accuracy_score
import numpy as np

# %%
sls = pd.read_csv("C:/Users/jwst2/Python/tesis/dataset/3200_sls.csv")
# Out:
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sls.head()
# Out:
#        id  kdprov  kdkab  kdkec  kddesa      iddesa  idslsnon  \
# 0  263884      32      1     10       1  3201010001       100
# 1  263885      32      1     10       1  3201010001       200
# 2  263886      32      1     10       1  3201010001       300
# 3  263887      32      1     10       1  3201010001       400
# 4  263888      32      1     10       1  3201010001       500
#
#                 nmslsnon              ketua_sls  jenis  ...  j_bstt  j_bsbtt  \
# 0  RT 001 RW 001 DUSUN 1  MUHAMAD RAFLI HIDAYAT      1  ...      39        1
# 1  RT 002 RW 001 DUSUN 1                 NURMAN      1  ...      60        2
# 2  RT 003 RW 001 DUSUN 1               SAENUDIN      1  ...      50        2
# 3  RT 004 RW 001 DUSUN 1                    AEP      1  ...      27        1
# 4  RT 005 RW 001 DUSUN 1          JEJEN JAELANI      1  ...      49        7
#
#    j_bstt_k  j_bskeko  j_segmen  dom  ldom  j_m_all j_m_30 klas_ur
# 0         2         4         1    1     1       51     51       2
# 1         0         7         1    1     1       62     61       2
# 2         0         6         1    1     1       58     57       2
# 3         0         1         1    1     1       31     31       2
# 4         3         8         3    1     1       63     57       2
#
# [5 rows x 36 columns]

# %%
sls.iddesa.unique().shape
# Out:
# (5957,)

# %%
ur_path = "C:/Users/jwst2/Python/tesis/jpg/UR/12. Resolution compare desa SPOT"
gen_path =  "C:/Users/jwst2/Python/tesis/jpg/general desa spot ES/"
test_path = 'C:/Users/jwst2/Python/tesis/jpg/UR/test sls 60m ES/'
model_code_dense = "D012"

# %%
os.chdir(ur_path)
if os.path.isdir('urban') is False:
    os.makedirs('urban')
    os.makedirs('rural')

# %%
yourpath = gen_path
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        try :
            if(sls.klas_ur[sls.iddesa == int(name.replace(".jpg","")[:10])].iloc[0] == 1):
                shutil.copy(os.path.join(root, name), ur_path+"/urban/"+name)
            elif(sls.klas_ur[sls.iddesa == int(name.replace(".jpg","")[:10])].iloc[0] == 2):
                shutil.copy(os.path.join(root, name),ur_path+ "/rural/"+name)
        except Exception:
            print(name)
            pass
# Out:
# 0it [00:00, ?it/s]
# 3211080000.jpg
# 3211111000.jpg
# 3217000000.jpg
# 1it [00:18, 18.81s/it]

# %% [markdown]
# #### Processing Image Input SPOT

# %%
path = Path.cwd() / (ur_path)

# %%
Path.BASE_PATH = path
path.ls()
# Out:
# (#2) [Path('rural'),Path('urban')]

# %%
fname = (path/"rural").ls()[0]
fname
# Out:
# Path('rural/3201010001.jpg')

# %%
img = Image.open(fname)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x1E0AEAEDD00>

# %%
blocks = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, # finds the images in the path
                 splitter=RandomSplitter(valid_pct=0.1, seed=42),  # default random split 80% training, 20% validation
                 get_y=parent_label # extracts the label category from the image's folder name 
                 ,item_tfms = Resize(224)) # data augmentation (mult multiplies the default transformation values)

# %%
dls = blocks.dataloaders(path, bs=4)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.show_batch(nrows=1, ncols=5)

# %%
avg = 'macro'
roca = RocAucBinary(average=avg)
f1s = F1Score(average=avg)
bc = BalancedAccuracy()
metrics=[accuracy,bc, Precision(average=avg), Recall(average=avg), f1s, roca]
learn = cnn_learner(dls, densenet121, metrics=metrics)

# %%
learn.fit_one_cycle(10)

# %%
learn.fit_one_cycle(10)

# %%
learn.export("C:/Users/jwst2/Python/tesis/models/19042022"+ model_code_dense+".pkl")

# %% [markdown]
# #### Processing Image Input Sentinel

# %%
split = pd.read_csv("C:/Users/jwst2/Python/tesis/dataset/01 datasplit_ur_desa_uncovered.csv")

# %%
ur_path = "C:/Users/jwst2/Python/tesis/jpg/UR/12. Resolution compare desa sentinel"
gen_path =  "C:/Users/jwst2/Python/tesis/jpg/general desa sentinel ES RES/"
test_path = 'C:/Users/jwst2/Python/tesis/jpg/UR/test sls 60m ES/'
root_path = "C:/Users/jwst2/Python/tesis/jpg/general desa sentinel ES/"
model_code_dense_2 = "D013"

# %%
for desa in split.iddesa:
    desa = str(desa)
    shutil.copy(root_path +desa+".jpg", gen_path+desa+".jpg")

# %%
os.chdir(ur_path)
if os.path.isdir('urban') is False:
    os.makedirs('urban')
    os.makedirs('rural')

# %%
yourpath = gen_path
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        try :
            if(sls.klas_ur[sls.iddesa == int(name.replace(".jpg","")[:10])].iloc[0] == 1):
                shutil.copy(os.path.join(root, name), ur_path+"/urban/"+name)
            elif(sls.klas_ur[sls.iddesa == int(name.replace(".jpg","")[:10])].iloc[0] == 2):
                shutil.copy(os.path.join(root, name),ur_path+ "/rural/"+name)
        except Exception:
            print(name)
            pass
# Out:
# 1it [00:21, 21.84s/it]

# %%
path = Path.cwd() / (ur_path)

# %%
blocks = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, # finds the images in the path
                 splitter=RandomSplitter(valid_pct=0.1, seed=42),  # default random split 80% training, 20% validation
                 get_y=parent_label # extracts the label category from the image's folder name 
                 ,item_tfms = Resize(128)) # data augmentation (mult multiplies the default transformation values)

# %%
dls = blocks.dataloaders(path,bs = 5)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.show_batch(nrows=1, ncols=5)

# %%
avg = 'macro'
roca = RocAucBinary(average=avg)
f1s = F1Score(average=avg)
bc = BalancedAccuracy()
metrics=[accuracy,bc, Precision(average=avg), Recall(average=avg), f1s, roca]
learn_sen = cnn_learner(dls, densenet121, metrics=metrics)

# %%
learn_sen.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.852940</td>
#       <td>0.647073</td>
#       <td>0.765363</td>
#       <td>0.661119</td>
#       <td>0.699044</td>
#       <td>0.661119</td>
#       <td>0.673358</td>
#       <td>0.742734</td>
#       <td>02:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.640646</td>
#       <td>0.532876</td>
#       <td>0.741155</td>
#       <td>0.653228</td>
#       <td>0.666364</td>
#       <td>0.653228</td>
#       <td>0.658655</td>
#       <td>0.756175</td>
#       <td>02:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.534959</td>
#       <td>0.500873</td>
#       <td>0.770950</td>
#       <td>0.617145</td>
#       <td>0.732652</td>
#       <td>0.617145</td>
#       <td>0.629229</td>
#       <td>0.768913</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.480389</td>
#       <td>0.392822</td>
#       <td>0.806331</td>
#       <td>0.713081</td>
#       <td>0.763236</td>
#       <td>0.713081</td>
#       <td>0.730390</td>
#       <td>0.870690</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.495060</td>
#       <td>0.406854</td>
#       <td>0.819367</td>
#       <td>0.698109</td>
#       <td>0.814522</td>
#       <td>0.698109</td>
#       <td>0.725519</td>
#       <td>0.868315</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.421206</td>
#       <td>0.480882</td>
#       <td>0.793296</td>
#       <td>0.669388</td>
#       <td>0.758054</td>
#       <td>0.669388</td>
#       <td>0.689981</td>
#       <td>0.815183</td>
#       <td>02:52</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.395361</td>
#       <td>0.369209</td>
#       <td>0.839851</td>
#       <td>0.764286</td>
#       <td>0.809540</td>
#       <td>0.764286</td>
#       <td>0.781790</td>
#       <td>0.886453</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.351033</td>
#       <td>0.370443</td>
#       <td>0.834264</td>
#       <td>0.777841</td>
#       <td>0.792443</td>
#       <td>0.777841</td>
#       <td>0.784527</td>
#       <td>0.884236</td>
#       <td>02:48</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.310377</td>
#       <td>0.396695</td>
#       <td>0.834264</td>
#       <td>0.747423</td>
#       <td>0.807830</td>
#       <td>0.747423</td>
#       <td>0.768639</td>
#       <td>0.869669</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.346049</td>
#       <td>0.387466</td>
#       <td>0.824953</td>
#       <td>0.749736</td>
#       <td>0.785373</td>
#       <td>0.749736</td>
#       <td>0.763945</td>
#       <td>0.871376</td>
#       <td>02:47</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_sen.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.324079</td>
#       <td>0.403987</td>
#       <td>0.823091</td>
#       <td>0.728906</td>
#       <td>0.793239</td>
#       <td>0.728906</td>
#       <td>0.750256</td>
#       <td>0.875792</td>
#       <td>02:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_sen.export("C:/Users/jwst2/Python/tesis/models/19042022"+ "D012B"+".pkl")

# %% [markdown]
# peningkatan resolusi gambar tidak meningkatkan akurasi dan presisi klasifikasi. Akan tetapi dengan data tersebut, akurasi yang dihasilkan lebih seimbang. Dari sisi lain data dengan resolusi lebih itnggi membutuhkan biaya pengumpulan data dan komputasi yang lebih mahal. Sehingga butuh pertimbangan lebih lanjut untuk menggunakan resolusi lebih tinggi untuk melakukan klasifikasi urban rural.
