# %%
import fastai
from fastai.vision.all import *
import pandas as pd

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np

# %%
sls = pd.read_csv("C:/Users/jwst2/Python/tesis/dataset/3200_sls.csv")
# Out:
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sls.head()
# Out:
#        id  kdprov  kdkab  kdkec  kddesa      iddesa  idslsnon  \
# 0  263884      32      1     10       1  3201010001       100
# 1  263885      32      1     10       1  3201010001       200
# 2  263886      32      1     10       1  3201010001       300
# 3  263887      32      1     10       1  3201010001       400
# 4  263888      32      1     10       1  3201010001       500
#
#                 nmslsnon              ketua_sls  jenis  ...  j_bstt  j_bsbtt  \
# 0  RT 001 RW 001 DUSUN 1  MUHAMAD RAFLI HIDAYAT      1  ...      39        1
# 1  RT 002 RW 001 DUSUN 1                 NURMAN      1  ...      60        2
# 2  RT 003 RW 001 DUSUN 1               SAENUDIN      1  ...      50        2
# 3  RT 004 RW 001 DUSUN 1                    AEP      1  ...      27        1
# 4  RT 005 RW 001 DUSUN 1          JEJEN JAELANI      1  ...      49        7
#
#    j_bstt_k  j_bskeko  j_segmen  dom  ldom  j_m_all j_m_30 klas_ur
# 0         2         4         1    1     1       51     51       2
# 1         0         7         1    1     1       62     61       2
# 2         0         6         1    1     1       58     57       2
# 3         0         1         1    1     1       31     31       2
# 4         3         8         3    1     1       63     57       2
#
# [5 rows x 36 columns]

# %%
sls.iddesa.unique().shape
# Out:
# (5957,)

# %%
yourpath = "C:/Users/jwst2/Python/tesis/jpg/jabartruecrop/"
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        try :
            if(sls.klas_ur[sls.iddesa == int(name.replace(".jpg","")[:10])].iloc[0] == 1):
                shutil.copy(os.path.join(root, name), "C:/Users/jwst2/Python/tesis/jpg/jabar10m_ur_truecrop/urban/"+name)
            elif(sls.klas_ur[sls.iddesa == int(name.replace(".jpg","")[:10])].iloc[0] == 2):
                shutil.copy(os.path.join(root, name), "C:/Users/jwst2/Python/tesis/jpg/jabar10m_ur_truecrop/rural/"+name)
        except Exception:
            print(name)
            pass
# Out:
# 0it [00:00, ?it/s]
# 3207000000.jpg
# 3208000000.jpg
# 3208010000.jpg
# 3211080000.jpg
# 3211111000.jpg
# 3217000000.jpg
# 1it [00:22, 22.61s/it]

# %% [markdown]
# ### Run Dataset

# %%
path = Path.cwd() / ("C:/Users/jwst2/Python/tesis/jpg/jabar10m_ur_truecrop")

# %%
Path.BASE_PATH = path
path.ls()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25572/3698979819.py in <module>
#       1 Path.BASE_PATH = path
# ----> 2 path.ls()
#
# ~\anaconda3\envs\datasc\lib\site-packages\fastcore\xtras.py in ls(self, n_max, file_type, file_exts)
#     274     res = (o for o in self.iterdir() if has_extns or o.suffix in extns)
#     275     if n_max is not None: res = itertools.islice(res, n_max)
# --> 276     return L(res)
#     277
#     278 # Cell
#
# ~\anaconda3\envs\datasc\lib\site-packages\fastcore\foundation.py in __call__(cls, x, *args, **kwargs)
#      95     def __call__(cls, x=None, *args, **kwargs):
#      96         if not args and not kwargs and x is not None and isinstance(x,cls): return x
# ---> 97         return super().__call__(x, *args, **kwargs)
#      98
#      99 # Cell
#
# ~\anaconda3\envs\datasc\lib\site-packages\fastcore\foundation.py in __init__(self, items, use_list, match, *rest)
#     103     def __init__(self, items=None, *rest, use_list=False, match=None):
#     104         if (use_list is not None) or not is_array(items):
# --> 105             items = listify(items, *rest, use_list=use_list, match=match)
#     106         super().__init__(items)
#     107
#
# ~\anaconda3\envs\datasc\lib\site-packages\fastcore\basics.py in listify(o, use_list, match, *rest)
#      54     elif isinstance(o, list): res = o
#      55     elif isinstance(o, str) or is_array(o): res = [o]
# ---> 56     elif is_iter(o): res = list(o)
#      57     else: res = [o]
#      58     if match is not None:
#
# ~\anaconda3\envs\datasc\lib\site-packages\fastcore\xtras.py in <genexpr>(.0)
#     272     if file_type: extns += L(k for k,v in mimetypes.types_map.items() if v.startswith(file_type+'/'))
#     273     has_extns = len(extns)==0
# --> 274     res = (o for o in self.iterdir() if has_extns or o.suffix in extns)
#     275     if n_max is not None: res = itertools.islice(res, n_max)
#     276     return L(res)
#
# ~\anaconda3\envs\datasc\lib\pathlib.py in iterdir(self)
#    1158         result for the special paths '.' and '..'.
#    1159         """
# -> 1160         for name in self._accessor.listdir(self):
#    1161             if name in {'.', '..'}:
#    1162                 # Yielding a path object for these makes little sense
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\jwst2\\Python\\tesis\\jpg\\jabar10m_ur_truecrop'

# %%
fname = (path/"rural").ls()[0]
fname

# %%
img = Image.open(fname)
img
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25572/1080359112.py in <module>
# ----> 1 img = Image.open(fname)
#       2 img
#
# NameError: name 'fname' is not defined

# %%
blocks = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, # finds the images in the path
                 splitter=RandomSplitter(valid_pct=0.1, seed=42),  # default random split 80% training, 20% validation
                 get_y=parent_label, # extracts the label category from the image's folder name 
                 batch_tfms=aug_transforms(mult=2)) # data augmentation (mult multiplies the default transformation values)

# %%
dls = blocks.dataloaders(path,bs=4)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\torch\_tensor.py:1023: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ..\aten\src\ATen\native\BatchLinearAlgebra.cpp:760.)
#   ret = func(*args, **kwargs)

# %%
dls.show_batch(nrows=1)

# %%
avg = 'macro'
roca = RocAucBinary(average=avg)
f1s = F1Score(average=avg)
bc = BalancedAccuracy()
metrics=[accuracy,bc, Precision(average=avg), Recall(average=avg), f1s, roca]
learn = cnn_learner(dls, densenet121, metrics=metrics) 
learn.summary()

# %%
learn.lr_find()

# %%
learn.fit_one_cycle(15)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.825821</td>
#       <td>0.562259</td>
#       <td>0.761345</td>
#       <td>0.739852</td>
#       <td>0.714715</td>
#       <td>0.739852</td>
#       <td>0.723151</td>
#       <td>0.820536</td>
#       <td>04:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.574132</td>
#       <td>0.671220</td>
#       <td>0.732773</td>
#       <td>0.734387</td>
#       <td>0.697616</td>
#       <td>0.734387</td>
#       <td>0.703136</td>
#       <td>0.792475</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.576982</td>
#       <td>0.460525</td>
#       <td>0.783193</td>
#       <td>0.713554</td>
#       <td>0.732621</td>
#       <td>0.713554</td>
#       <td>0.721524</td>
#       <td>0.826252</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.553036</td>
#       <td>0.397740</td>
#       <td>0.810084</td>
#       <td>0.784641</td>
#       <td>0.766101</td>
#       <td>0.784641</td>
#       <td>0.773910</td>
#       <td>0.883963</td>
#       <td>04:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.519959</td>
#       <td>0.402457</td>
#       <td>0.796639</td>
#       <td>0.748195</td>
#       <td>0.749098</td>
#       <td>0.748195</td>
#       <td>0.748643</td>
#       <td>0.865493</td>
#       <td>04:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0