# %% [markdown]
# # UR SLS Comparison SPOT ES

# %% [markdown]
# Dari hasil sebelumnya, dapat dilihat densenet121 adalah model terbaik untuk mengklasfikari desa urban dan rural dengan model data : SLS dan Square Neighbour. Skenario tersebut akan digunakan untuk menguji efek resolusi terhadap klasifikasi dengan melakukan train terhadapa uncovered desa baik dengan data sentinel maupun spot.
#
# Pada proses clipping citra , ditemukan 577 desa dengan tutupan awan tinggi untuk satelit SPOT 6-7 seperti yang dapat dilihat pada Gambar 6. Sehingga pada kajian efek resolusi citra terhadap model akan dilakukan pada 5380 desa dan 200.200 SLS.

# %% [markdown]
# #### Import Fast AI

# %%
import fastai
from fastai.vision.all import *
import pandas as pd

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,roc_auc_score,balanced_accuracy_score
import numpy as np

# %%
sls = pd.read_csv("C:/Users/jwst2/Python/tesis/dataset/3200_sls.csv")
# Out:
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sls.head()
# Out:
#        id  kdprov  kdkab  kdkec  kddesa      iddesa  idslsnon  \
# 0  263884      32      1     10       1  3201010001       100
# 1  263885      32      1     10       1  3201010001       200
# 2  263886      32      1     10       1  3201010001       300
# 3  263887      32      1     10       1  3201010001       400
# 4  263888      32      1     10       1  3201010001       500
#
#                 nmslsnon              ketua_sls  jenis  ...  j_bstt  j_bsbtt  \
# 0  RT 001 RW 001 DUSUN 1  MUHAMAD RAFLI HIDAYAT      1  ...      39        1
# 1  RT 002 RW 001 DUSUN 1                 NURMAN      1  ...      60        2
# 2  RT 003 RW 001 DUSUN 1               SAENUDIN      1  ...      50        2
# 3  RT 004 RW 001 DUSUN 1                    AEP      1  ...      27        1
# 4  RT 005 RW 001 DUSUN 1          JEJEN JAELANI      1  ...      49        7
#
#    j_bstt_k  j_bskeko  j_segmen  dom  ldom  j_m_all j_m_30 klas_ur
# 0         2         4         1    1     1       51     51       2
# 1         0         7         1    1     1       62     61       2
# 2         0         6         1    1     1       58     57       2
# 3         0         1         1    1     1       31     31       2
# 4         3         8         3    1     1       63     57       2
#
# [5 rows x 36 columns]

# %%
sls.iddesa.unique().shape
# Out:
# (5957,)

# %%
ur_path = "C:/Users/jwst2/Python/tesis/jpg/UR/13. Resolution compare sls SPOT"
gen_path =  "C:/Users/jwst2/Python/tesis/jpg/general sls spot ES RES/"
test_path = 'C:/Users/jwst2/Python/tesis/jpg/UR/test sls spot ES RES/'
model_code_resnet = "R013"
model_code_dense = "D013"

# %%
os.chdir(ur_path)
if os.path.isdir('urban') is False:
    os.makedirs('urban')
    os.makedirs('rural')

# %%
yourpath = gen_path
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        try :
            if(sls.klas_ur[sls.iddesa == int(name.replace(".jpg","")[:10])].iloc[0] == 1):
                shutil.copy(os.path.join(root, name), ur_path+"/urban/"+name)
            elif(sls.klas_ur[sls.iddesa == int(name.replace(".jpg","")[:10])].iloc[0] == 2):
                shutil.copy(os.path.join(root, name),ur_path+ "/rural/"+name)
        except Exception:
            print(name)
            pass
# Out:
# 1it [13:39, 819.28s/it]

# %%
split = pd.read_csv("C:/Users/jwst2/Python/tesis/dataset/01 datasplit_ur_desa_uncovered.csv")

# %%
split.head()
# Out:
#        iddesa  klas_ur   stat
# 0  3207110010        1  train
# 1  3205200018        1  train
# 2  3210070011        1  train
# 3  3211010004        1  train
# 4  3201290007        1  train

# %%
split_test =split[split["stat"] == "test"]

# %%
split_test
# Out:
#           iddesa  klas_ur  stat
# 4840  3213080006        2  test
# 4841  3212081006        2  test
# 4842  3276050006        1  test
# 4843  3203010002        2  test
# 4844  3208161002        1  test
# ...          ...      ...   ...
# 5373  3276040009        1  test
# 5374  3214070007        1  test
# 5375  3209120023        1  test
# 5376  3202280008        1  test
# 5377  3201150002        2  test
#
# [538 rows x 3 columns]

# %% [markdown]
# #### Pembentukan test set

# %%
os.chdir(test_path)
if os.path.isdir('urban') is False:
    os.makedirs('urban')
    os.makedirs('rural')

# %%
yourpath = ur_path+ "/rural"
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        try :
            if(split_test.iddesa.astype(str).str.contains(name[:10]).sum() > 0):
                shutil.move(os.path.join(root, name),test_path + "/rural/"+name)
        except Exception:
            print(name)
            pass
# Out:
# 1it [00:26, 26.61s/it]

# %%
yourpath =  ur_path+ "/urban"
from tqdm import tqdm
for root, dirs, files in tqdm(os.walk(yourpath, topdown=False)):
    for name in files:
        try :
            if(split_test.iddesa.astype(str).str.contains(name[:10]).sum() > 0):
                shutil.move(os.path.join(root, name), test_path +"/urban/"+name)
        except Exception:
            print(name)
            pass
# Out:
# 1it [01:45, 105.52s/it]

# %% [markdown]
# #### Processing data SPOT tingkat SLS

# %%
path = Path.cwd() / (ur_path)

# %%
Path.BASE_PATH = path
path.ls()
# Out:
# (#2) [Path('rural'),Path('urban')]

# %%
fname = (path/"rural").ls()[0]
fname
# Out:
# Path('rural/32010100010001.jpg')

# %%
img = Image.open(fname)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=721x721 at 0x20EECE5CCA0>

# %%
blocks = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, # finds the images in the path
                 splitter=RandomSplitter(valid_pct=0.1, seed=42),  # default random split 80% training, 20% validation
                 get_y=parent_label # extracts the label category from the image's folder name 
                 ,item_tfms = Resize(64)) # data augmentation (mult multiplies the default transformation values)

# %%
dls = blocks.dataloaders(path)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.show_batch(nrows=1, ncols=5)

# %%
avg = 'macro'
roca = RocAucBinary(average=avg)
f1s = F1Score(average=avg)
bc = BalancedAccuracy()
metrics=[accuracy,bc, Precision(average=avg), Recall(average=avg), f1s, roca]
learn = cnn_learner(dls, densenet121, metrics=metrics)

# %%
learn.fit_one_cycle(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.366045</td>
#       <td>0.342552</td>
#       <td>0.841518</td>
#       <td>0.676393</td>
#       <td>0.759919</td>
#       <td>0.676393</td>
#       <td>0.702876</td>
#       <td>0.864192</td>
#       <td>34:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.335703</td>
#       <td>0.328070</td>
#       <td>0.847037</td>
#       <td>0.711890</td>
#       <td>0.762676</td>
#       <td>0.711890</td>
#       <td>0.731795</td>
#       <td>0.878105</td>
#       <td>27:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.323391</td>
#       <td>0.323424</td>
#       <td>0.849992</td>
#       <td>0.700554</td>
#       <td>0.774350</td>
#       <td>0.700554</td>
#       <td>0.726433</td>
#       <td>0.881146</td>
#       <td>27:12</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>balanced_accuracy_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.348885</td>
#       <td>0.340901</td>
#       <td>0.842076</td>
#       <td>0.659788</td>
#       <td>0.771004</td>
#       <td>0.659788</td>
#       <td>0.689360</td>
#       <td>0.868310</td>
#       <td>30:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.362182</td>
#       <td>0.426533</td>
#       <td>0.834495</td>
#       <td>0.639637</td>
#       <td>0.755282</td>
#       <td>0.639637</td>
#       <td>0.666715</td>
#       <td>0.851405</td>
#       <td>30:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.350703</td>
#       <td>0.346300</td>
#       <td>0.839623</td>
#       <td>0.690655</td>
#       <td>0.750037</td>
#       <td>0.690655</td>
#       <td>0.712296</td>
#       <td>0.863216</td>
#       <td>30:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.357827</td>
#       <td>0.351574</td>
#       <td>0.837059</td>
#       <td>0.672326</td>
#       <td>0.748446</td>
#       <td>0.672326</td>
#       <td>0.696932</td>
#       <td>0.857565</td>
#       <td>29:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.323142</td>
#       <td>0.328345</td>
#       <td>0.845922</td>
#       <td>0.714112</td>
#       <td>0.759542</td>
#       <td>0.714112</td>
#       <td>0.732370</td>
#       <td>0.879209</td>
#       <td>29:48</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.328259</td>
#       <td>0.346518</td>
#       <td>0.846758</td>
#       <td>0.672200</td>
#       <td>0.779855</td>
#       <td>0.672200</td>
#       <td>0.702760</td>
#       <td>0.882091</td>
#       <td>30:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.320579</td>
#       <td>0.316865</td>
#       <td>0.850828</td>
#       <td>0.717485</td>
#       <td>0.770279</td>
#       <td>0.717485</td>
#       <td>0.738173</td>
#       <td>0.887228</td>
#       <td>30:34</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.291773</td>
#       <td>0.315429</td>
#       <td>0.851887</td>
#       <td>0.705619</td>
#       <td>0.777530</td>
#       <td>0.705619</td>
#       <td>0.731282</td>
#       <td>0.890797</td>
#       <td>31:03</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.271571</td>
#       <td>0.322745</td>
#       <td>0.849100</td>
#       <td>0.729583</td>
#       <td>0.763378</td>
#       <td>0.729583</td>
#       <td>0.744068</td>
#       <td>0.888668</td>
#       <td>30:27</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.276322</td>
#       <td>0.323271</td>
#       <td>0.846981</td>
#       <td>0.726971</td>
#       <td>0.759390</td>
#       <td>0.726971</td>
#       <td>0.740915</td>
#       <td>0.888141</td>
#       <td>54:37</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
dls.vocab
# Out:
# ['rural', 'urban']

# %%
dls.train.items[17000]
# Out:
# Path('urban/32710400040026.jpg')

# %%
learn.export("C:/Users/jwst2/Python/tesis/models/19042022"+ model_code_dense+".pkl")

# %% [markdown]
# ### Up level

# %% [markdown]
# ![image.png](attachment:49d54594-f491-45de-9d27-af4c69b3c454.png)![image.png](attachment:ebe81534-b0be-40f1-a09a-864e9b207ea6.png)

# %%
idx_train = []
for i in dls.train.items:
    idx_train.append(str(i)[-18:-4])
true_label = []
for i in dls.train.items:
    if("urban" in str(i)) :
        true_label.append(1)
    else :
        true_label.append(0)

# %%
preds,_ = learn.get_preds(ds_idx  = 0)
result_train = preds.numpy()
new_train = pd.DataFrame(result_train)
# Out:
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\jwst2\anaconda3\envs\datasc\lib\site-packages\PIL\Image.py:2918: DecompressionBombWarning: Image size (123587689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
pd.value_counts(true_label)
# Out:
# 1    129800
# 0     31652
# dtype: int64

# %%
df = new_train
df["idsls"] = idx_train 
df["stat"] = round(df[1])
df["iddesa"] = df.idsls.str[:10]
df.head()
# Out:
#               0         1           idsls  stat      iddesa
# 0  9.357719e-04  0.999064  32110300100010   1.0  3211030010
# 1  3.762362e-02  0.962376  32151500010027   1.0  3215150001
# 2  4.291864e-01  0.570814  32111710040030   1.0  3211171004
# 3  4.305440e-01  0.569456  32021000040016   1.0  3202100004
# 4  1.135220e-07  1.000000  32160900010100   1.0  3216090001

# %%
pd.value_counts(df.stat)
# Out:
# 1.0    134250
# 0.0     27202
# Name: stat, dtype: int64

# %%
df["true_lab"] = true_label

# %%
pd.value_counts(df.true_lab)
# Out:
# 1    129800
# 0     31652
# Name: true_lab, dtype: int64

# %%
accuracy_score(df.stat.apply(int),df.true_lab.apply(int))
# Out:
# 0.8822931893070386

# %%
df.head()
# Out:
#               0         1           idsls  stat      iddesa  true_lab
# 0  9.357719e-04  0.999064  32110300100010   1.0  3211030010         1
# 1  3.762362e-02  0.962376  32151500010027   1.0  3215150001         1
# 2  4.291864e-01  0.570814  32111710040030   1.0  3211171004         1
# 3  4.305440e-01  0.569456  32021000040016   1.0  3202100004         0
# 4  1.135220e-07  1.000000  32160900010100   1.0  3216090001         1

# %%
desa_pred = df.groupby('iddesa').agg({'stat': ['mean'], 'true_lab': 'mean'})

# %%
desa_pred.columns = ["pred","true"]

# %%
pd.value_counts(df.stat)
# Out:
# 1.0    134250
# 0.0     27202
# Name: stat, dtype: int64

# %%
for i in np.arange(0.1, 0.95, 0.025):
    value = round(i,2)
    desa_pred["label"+str(value)] = 0
    desa_pred["label"+str(value)][desa_pred.pred > value] = 1
# Out:
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_18456/935834860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred["label"+str(value)][desa_pred.pred > value] = 1
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_18456/935834860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred["label"+str(value)][desa_pred.pred > value] = 1
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_18456/935834860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred["label"+str(value)][desa_pred.pred > value] = 1
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_18456/935834860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred["label"+str(value)][desa_pred.pred > value] = 1
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_18456/935834860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred["label"+str(value)][desa_pred.pred > value] = 1
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_18456/935834860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred["label"+str(value)][desa_pred.pred > value] = 1
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_18456/935834860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred["label"+str(value)][desa_pred.pred > value] = 1
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_18456/935834860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred["label"+str(value)][desa_pred.pred > value] = 1

# %%
desa_pred.head()
# Out:
#                 pred  true  label0.1  label0.12  label0.15  label0.18  \
# iddesa
# 3201010001  0.185185   0.0         1          1          1          1
# 3201010003  0.717949   1.0         1          1          1          1
# 3201010004  0.555556   0.0         1          1          1          1
# 3201010005  0.548387   1.0         1          1          1          1
# 3201010006  0.310345   0.0         1          1          1          1
#
#             label0.2  label0.22  label0.25  label0.27  ...  label0.7  \
# iddesa                                                 ...
# 3201010001         0          0          0          0  ...         0
# 3201010003         1          1          1          1  ...         1
# 3201010004         1          1          1          1  ...         0
# 3201010005         1          1          1          1  ...         0
# 3201010006         1          1          1          1  ...         0
#
#             label0.72  label0.75  label0.77  label0.8  label0.82  label0.85  \
# iddesa
# 3201010001          0          0          0         0          0          0
# 3201010003          0          0          0         0          0          0
# 3201010004          0          0          0         0          0          0
# 3201010005          0          0          0         0          0          0
# 3201010006          0          0          0         0          0          0
#
#             label0.87  label0.9  label0.92
# iddesa
# 3201010001          0         0          0
# 3201010003          0         0          0
# 3201010004          0         0          0
# 3201010005          0         0          0
# 3201010006          0         0          0
#
# [5 rows x 36 columns]

# %%
for j in range(2,36):
    print("result", desa_pred.columns[j])
    print("accuracy :",  accuracy_score( desa_pred.true,desa_pred.iloc[:,[j]]))
    print("precision :",  precision_score( desa_pred.true,desa_pred.iloc[:,[j]]))
# Out:
# result label0.1
# accuracy : 0.7863636363636364
# precision : 0.7769097222222222
# result label0.12
# accuracy : 0.7909090909090909
# precision : 0.7810043668122271
# result label0.15
# accuracy : 0.7975206611570248
# precision : 0.7870044052863436
# result label0.18
# accuracy : 0.8072314049586777
# precision : 0.7956318252730109
# result label0.2
# accuracy : 0.8159090909090909
# precision : 0.8036961911201262
# result label0.22
# accuracy : 0.821900826446281
# precision : 0.808983666061706
# result label0.25
# accuracy : 0.8353305785123967
# precision : 0.821683967704729
# result label0.27
# accuracy : 0.8373966942148761
# precision : 0.8241834607366226
# result label0.3
# accuracy : 0.8477272727272728
# precision : 0.8341543513957307
# result label0.32
# accuracy : 0.8541322314049586
# precision : 0.8407477520113582
# result label0.35
# accuracy : 0.8613636363636363
# precision : 0.8487676477626226
# result label0.37
# accuracy : 0.8673553719008265
# precision : 0.8553838725253501
# result label0.4
# accuracy : 0.8774793388429752
# precision : 0.8685052942624969
# result label0.42
# accuracy : 0.8805785123966943
# precision : 0.8726461843409317
# result label0.45
# accuracy : 0.8871900826446281
# precision : 0.8807615230460922
# result label0.47
# accuracy : 0.8888429752066116
# precision : 0.8850429509853461
# result label0.5
# accuracy : 0.8983471074380165
# precision : 0.8995351239669421
# result label0.52
# accuracy : 0.9006198347107438
# precision : 0.9023062969681265
# result label0.55
# accuracy : 0.9057851239669421
# precision : 0.9131467793030623
# result label0.57
# accuracy : 0.9066115702479339
# precision : 0.9165337586390218
# result label0.6
# accuracy : 0.9103305785123967
# precision : 0.9264069264069265
# result label0.62
# accuracy : 0.9119834710743802
# precision : 0.9298150163220892
# result label0.65
# accuracy : 0.9138429752066116
# precision : 0.9383125864453665
# result label0.67
# accuracy : 0.9117768595041322
# precision : 0.9433062026382262
# result label0.7
# accuracy : 0.9109504132231405
# precision : 0.9503282900371111
# result label0.72
# accuracy : 0.9099173553719008
# precision : 0.9554655870445344
# result label0.75
# accuracy : 0.9041322314049587
# precision : 0.9640309155766944
# result label0.77
# accuracy : 0.9004132231404959
# precision : 0.966066066066066
# result label0.8
# accuracy : 0.890495867768595
# precision : 0.9721878862793573
# result label0.82
# accuracy : 0.8822314049586777
# precision : 0.9736180904522613
# result label0.85
# accuracy : 0.8650826446280991
# precision : 0.9797186784429179
# result label0.87
# accuracy : 0.8522727272727273
# precision : 0.9825210084033613
# result label0.9
# accuracy : 0.8239669421487603
# precision : 0.9854403409090909
# result label0.92
# accuracy : 0.7987603305785124
# precision : 0.9887724550898204

# %%
pd.value_counts(desa_pred.true)
# Out:
# 1.0    3586
# 0.0    1254
# Name: true, dtype: int64

# %% [markdown]
# ### Test result

# %%
path_pred = Path.cwd() / (test_path)
test_files = [fn for fn in sorted((path_pred).glob('**/*')) if fn.is_file()]

# %%
len(test_files)
# Out:
# 20905

# %%
test_dl = learn.dls.test_dl(test_files)

# %%
preds,_ = learn.get_preds(dl  =test_dl)

# %%
str(test_files[1])[-18:-4]
# Out:
# '32010100020002'

# %%
idx_test = []
for i in test_files:
    idx_test.append(str(i)[-18:-4])
true_label = []
for i in test_files:
    if("urban" in str(i)) :
        true_label.append(1)
    else :
        true_label.append(0)

# %%
test = pd.DataFrame(preds)

# %%
test["idsls"] = idx_test
test["true_lab"] = true_label

# %%
test["iddesa"] = test.idsls.str[:10]
test["stat"] = round(test[1])

# %%
test.head()
# Out:
#           0         1           idsls  true_lab      iddesa  stat
# 0  0.808513  0.191487  32010100020001         0  3201010002   0.0
# 1  0.586067  0.413933  32010100020002         0  3201010002   0.0
# 2  0.609961  0.390039  32010100020003         0  3201010002   0.0
# 3  0.710484  0.289516  32010100020004         0  3201010002   0.0
# 4  0.872367  0.127633  32010100020005         0  3201010002   0.0

# %%
desa_pred_test = test.groupby('iddesa').agg({'stat': ['mean'], 'true_lab': 'mean'})

# %%
desa_pred_test
# Out:
#                 stat true_lab
#                 mean     mean
# iddesa
# 3201010002  0.750000      0.0
# 3201020016  1.000000      1.0
# 3201021008  0.833333      1.0
# 3201030012  1.000000      1.0
# 3201040007  1.000000      1.0
# ...              ...      ...
# 3278031006  1.000000      1.0
# 3279010001  0.517241      1.0
# 3279010007  0.913043      1.0
# 3279020004  0.870968      1.0
# 3279030006  0.946809      1.0
#
# [538 rows x 2 columns]

# %%
desa_pred_test.columns = ["pred","true"]

# %%
desa_pred_test["pred_lab"] = 0
desa_pred_test["pred_lab"][desa_pred_test.pred > 0.775] = 1
# Out:
# C:\Users\jwst2\AppData\Local\Temp/ipykernel_18456/2742235302.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_pred_test["pred_lab"][desa_pred_test.pred > 0.775] = 1

# %%
print("accuracy :",  accuracy_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("balanced_accuracy_score :",  balanced_accuracy_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("precision :",  precision_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("recall :",  recall_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("f1 :",  f1_score( desa_pred_test.true,desa_pred_test.pred_lab))
print("rocauc :",  roc_auc_score( desa_pred_test.true,desa_pred_test.pred_lab))
# Out:
# accuracy : 0.8271375464684015
# balanced_accuracy_score : 0.8044508255563532
# precision : 0.9088471849865952
# recall : 0.8517587939698492
# f1 : 0.8793774319066148
# rocauc : 0.8044508255563532
